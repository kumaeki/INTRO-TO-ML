# %% [markdown]
# # The Probability of Spam Email
#
# - We have three spam emails and one of them contains the word 'easy'
#
# - two out of the three three spam emails containing the word 'money'
#
# - there are five ham emails and one of them contains the word 'easy'
#
# - And one of them contains the word 'moneny'
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## consider the word 'easy'
#
# - The probability of being spam email and containing the word 'easy' is $\frac{ 3}{ 8}*{\frac 1 3} = {\frac 1 8} $
#
# - The probability of being spam and not containing the word 'easy' is ${\frac 3 8}*{\frac 2 3} = {\frac 1 4} $
#
# - The probability of being ham and containing the word 'easy' is $ {\frac 5 8}*{\frac 1 5} = {\frac 1 8} $
#
# - The probability of being ham and not containing the word 'easy' is ${\frac 5 8}*{\frac 4 5} = {\frac 1 2} $
#
# ### So when the Email contains 'easy'
#
# - the probability of being Spam is ${\frac 1 2} $
#
# - the probability of being Ham is ${\frac 1 2} $
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## consider the word 'money'
#
# - The probability of being spam email and containing the word 'money' is ${\frac 3 8}*{\frac 2 3} = {\frac 1 4} $
#
# - The probability of being spam and not containing the word 'money' is ${\frac 3 8}*{\frac 1 3} = {\frac 1 4} $
#
# - The probability of being ham and containing the word 'money' is ${\frac 5 8}*{\frac 1 5} = {\frac 1 8} $
#
# - The probability of being ham and not containing the word 'money' is ${\frac 5 8}*{\frac 4 5} = {\frac 1 2} $
#
# ### So when the Email contains 'easy'
#
# - the probability of being Spam is ${\frac 2 3} $
#
# - the probability of being Ham is ${\frac 1 3} $
#
# ![image.png](attachment:image.png)
