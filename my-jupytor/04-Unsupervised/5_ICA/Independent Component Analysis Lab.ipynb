# %% [markdown]
# # Independent Component Analysis Lab
#
# In this notebook, we'll use Independent Component Analysis to retrieve original signals from three observations each of which contains a different mix of the original signals. This is the same problem explained in the ICA video.
#
# ## Dataset
# Let's begin by looking at the dataset we have. We have three WAVE files, each of which is a mix, as we've mentioned. If you haven't worked with audio files in python before, that's okay, they basically boil down to being lists of floats.
#
#
# Let's begin by loading our first audio file, **[ICA mix 1.wav](ICA mix 1.wav)** [click to listen to the file]:

# %%
mix_1_wave.close()

# %%
import numpy as np
import wave

# Read the wave file
mix_1_wave = wave.open('./ICA mix 1.wav','r')

# %% [markdown]
# Let's peak at the parameters of the wave file to learn more about it

# %%
mix_1_wave.getparams()
# Out:
# _wave_params(nchannels=1, sampwidth=2, framerate=44100, nframes=264515, comptype='NONE', compname='not compressed')

# %% [markdown]
# So this file has only channel (so it's mono sound). It has a frame rate of 44100, which means each second of sound is represented by 44100 integers (integers because the file is in the common PCM 16-bit format). The file has a total of 264515 integers/frames, which means its length in seconds is:

# %%
264515/44100
# Out:
# 5.998072562358277

# %% [markdown]
# Let's extract the frames of the wave file, which will be a part of the dataset we'll run ICA against:

# %%
# Extract Raw Audio from Wav File
signal_1_raw = mix_1_wave.readframes(-1)
print(signal_1_raw)
# Out:
# b'o\x03\xf4\x04\xb4\x05\xdc\x06\x97\x07\xa8\x08g\tl\n2\x0b"\x0c\xec\x0c\xda\r\xa8\x0e\x8d\x0fO\x10+\x11\xec\x11\xb6\x12f\x13\x1a\x14\xac\x14<\x15\xae\x15\x0b\x16U\x16\x7f\x16\x9e\x16\xa6\x16\x9d\x16|\x16Q\x16\x11\x16\xc8\x15f\x15\x05\x15\x93\x14\x1a\x14\x87\x13\xf8\x12J\x12\x96\x11\xd4\x10\x01\x10#\x0f5\x0e4\r#\x0c\t\x0b\xd2\t\x92\x087\x07\xc0\x05?\x04\x9f\x02\xe3\x00%\xffM\xfdh\xfb~\xf9\x89\xf7\x93\xf5\x95\xf3\xac\xf1\xb6\xef\xdd\xed\x04\xecI\xea\x9f\xe8\x14\xe7\x93\xe5?\xe4\x02\xe3\xe6\xe1\xed\xe0\x1d\xe0m\xdf\xea\xde\x93\xdeh\xdeV\xdew\xde\xb4\xde\x17\xdf\x96\xdf?\xe0\xf5\xe0\xd8\xe1\xcd\xe2\xdb\xe3\xfc\xe42\xe6\x86\xe7\xde\xe8L\xea\xd3\xebZ\xed\xff\xee\xae\xf0l\xf23\xf4\x0f\xf6\xee\xf7\xdc\xf9\xce\xfb\xc9\xfd\xc3\xff\xb6\x01\xb2\x03\x9d\x05\x89\x07b\t0\x0b\xf2\x0c\xa4\x0e@\x10\xcb\x11I\x13\xab\x14\xfa\x158\x17T\x18f\x19Z\x1a0\x1b\xee\x1b\x8a\x1c\x0e\x1du\x1d\xb8\x1d\xdb\x1d\xd2\x1d\xb7\x1dc\x1d\xf1\x1c^\x1c\xa5\x1b\xce\x1a\xd4\x19\xc5\x18\x92\x17X\x16\xfc\x14\x9d\x13!\x12\xa6\x10\x11\x0fz\r\xdf\x0b@\n\x97\x08\xe8\x06;\x05\x8c\x03\xd5\x01%\x00v\xfe\xc8\xfc\x1c\xfby\xf9\xd9\xf7O\xf6\xce\xf4d\xf3\x10\xf2\xd0\xf0\xb0\xef\xa7\xee\xbf\xed\xf3\xecC\xec\xb3\xebF\xeb\xfd\xea\xda\xea\xcf\xea\xe9\xea!\xeb|\xeb\xf2\xebz\xec\x10\xed\xb6\xeda\xee\r\xef\xbb\xefp\xf0\x1c\xf1\xc8\xf1d\xf2\xff\xf2\x97\xf3*\xf4\xb3\xf4?\xf5\xcf\xf5c\xf6\xf7\xf6\x8d\xf7+\xf8\xd4\xf8|\xf96\xfa\xe5\xfa\xb0\xfbo\xfcF\xfd\x15\xfe\xfa\xfe\xdf\xff\xc1\x00\xb9\x01\xab\x02\xa9\x03\xa7\x04\xa5\x05\xa6\x06\xa3\x07\x9e\x08\x92\t|\n^\x0b.\x0c\xe8\x0c\xa1\rB\x0e\xd0\x0eB\x0f\xac\x0f\xf7\x0f6\x10]\x10p\x10q\x10[\x109\x10\xfe\x0f\xb6\x0f`\x0f\xf7\x0ey\x0e\xf0\rS\r\xab\x0c\xf0\x0b0\x0bf\n\x9b\t\xc8\x08\xf1\x07\x19\x07;\x06e\x05z\x04\x9e\x03\xb9\x02\xd7\x01\xf7\x00\x1d\x00D\xffd\xfe\x87\xfd\xad\xfc\xce\xfb\xf3\xfa\x1f\xfaP\xf9\x86\xf8\xbc\xf7\xfe\xf6@\xf6\x93\xf5\xec\xf4Z\xf4\xce\xf3e\xf3\xf9\xf2\xae\xf2f\xf2?\xf2*\xf2#\xf20\xf2Q\xf2\x81\xf2\xc6\xf2\x1d\xf3{\xf3\xeb\xf3j\xf4\x01\xf5\xa5\xf5S\xf6\x1f\xf7\xee\xf7\xd0\xf8\xc7\xf9\xc8\xfa\xd4\xfb\xf1\xfc\x16\xfeI\xff\x85\x00\xcd\x01\'\x03\x83\x04\xf6\x05o\x07\xe9\x08h\n\xe0\x0bD\r\xa4\x0e\xeb\x0f\x17\x117\x12*\x13\x03\x14\xb0\x149\x15\x97\x15\xce\x15\xe0\x15\xcc\x15\x9a\x15>\x15\xc8\x14(\x14u\x13\x92\x12\xa1\x11\xa4\x10\x81\x0fE\x0e\x0f\r\xbb\x0b`\n\xfb\x08\x9d\x07*\x06\xc7\x04u\x03\x19\x02\xc9\x00\x8d\xffR\xfe&\xfd\x08\xfc\xef\xfa\xda\xf9\xdc\xf8\xd8\xf7\xdc\xf6\xe7\xf5\xe8\xf4\xf3\xf3\n\xf3\x1e\xf2#\xf1R\xf0\x82\xef\x9c\xee\xf8\xedV\xed\xb4\xec7\xec\xe8\xeb\x7f\xebK\xeb1\xeb\x1c\xeb\r\xeb3\xebB\xebf\xeb\xa9\xeb\x03\xec]\xec\xdf\xecv\xed\x17\xee\xce\xee\xa7\xef\x89\xf0w\xf1\x8e\xf2\x9b\xf3\xb8\xf4\xe1\xf5\n\xf7+\xf8S\xf9r\xfa\x88\xfb\x90\xfc\x9e\xfd\x92\xfez\xffa\x00<\x01\x02\x02\xcc\x02\x84\x030\x04\xd9\x04w\x05\x14\x06\xa9\x06>\x07\xd6\x07`\x08\xf9\x08\x8a\t(\n\xbf\n\\\x0b\xfa\x0b\x8f\x0c4\r\xbc\rQ\x0e\xd2\x0eU\x0f\xc8\x0f8\x10\xa1\x10\xfd\x10K\x11\x90\x11\xbf\x11\xe5\x11\xf6\x11\xf9\x11\xea\x11\xd3\x11\xb1\x11\x83\x11L\x11\n\x11\xbc\x10l\x10\x01\x10\x8e\x0f\x01\x0fd\x0e\xb5\r\xe0\x0c\xf1\x0b\xee\n\xc0\t\x84\x08+\x07\xc1\x05D\x04\xc2\x02/\x01\x8c\xff\xf0\xfdH\xfc\xa8\xfa\xfd\xf8Y\xf7\xba\xf5 \xf4\x91\xf2\x0f\xf1\x97\xef<\xee\xf5\xec\xc0\xeb\xb0\xea\xbf\xe9\xe3\xe8,\xe8\x97\xe7&\xe7\xd3\xe6\x9c\xe6\x89\xe6\x88\xe6\xa5\xe6\xe3\xe6*\xe7\x91\xe7\x04\xe8\x8b\xe8&\xe9\xce\xe9\x7f\xeaD\xeb\x0b\xec\xf4\xec\xd4\xed\xd8\xee\xd7\xef\xf9\xf0"\xf2_\xf3\xa4\xf4\xf7\xf5K\xf7\xb4\xf8\x1b\xfa\x94\xfb\x12\xfd\x95\xfe\'\x00\xbc\x01a\x03\x0b\x05\xbf\x06z\x083\n\xf5\x0b\xa8\ra\x0f\x08\x11\xa9\x12-\x14\xa7\x15\xf7\x168\x18N\x19I\x1a \x1b\xd3\x1ba\x1c\xcf\x1c\x15\x1dC\x1dC\x1d(\x1d\xe9\x1c\x85\x1c\x03\x1c^\x1b\x96\x1a\xb7\x19\xb2\x18\xa0\x17q\x16/\x15\xe0\x13\x8f\x12)\x11\xcc\x0ff\x0e\xfb\x0c\x91\x0b)\n\xc1\x08e\x07\x01\x06\xb3\x04Q\x03\x07\x02\xbc\x00r\xff-\xfe\xeb\xfc\xa8\xfbh\xfa.\xf9\xfb\xf7\xcf\xf6\xab\xf5\xa1\xf4\x99\xf3\xae\xf2\xd5\xf1\x13\xf1r\xf0\xed\xefv\xef!\xef\xd5\xee\xaa\xee\x86\xeey\xeew\xee\x85\xee\x9f\xee\xbc\xee\xe8\xee\x1c\xefJ\xe ...

# %%
signal_1 = np.frombuffer(signal_1_raw, dtype='int16')

# %% [markdown]
# signal_1 is now a list of ints representing the sound contained in the first file.

# %%
'length: ', len(signal_1) , 'first 100 elements: ',signal_1[:100]
# Out:
# ('length: ',
#  264515,
#  'first 100 elements: ',
#  array([  879,  1268,  1460,  1756,  1943,  2216,  2407,  2668,  2866,
#          3106,  3308,  3546,  3752,  3981,  4175,  4395,  4588,  4790,
#          4966,  5146,  5292,  5436,  5550,  5643,  5717,  5759,  5790,
#          5798,  5789,  5756,  5713,  5649,  5576,  5478,  5381,  5267,
#          5146,  4999,  4856,  4682,  4502,  4308,  4097,  3875,  3637,
#          3380,  3107,  2825,  2514,  2194,  1847,  1472,  1087,   671,
#           227,  -219,  -691, -1176, -1666, -2167, -2669, -3179, -3668,
#         -4170, -4643, -5116, -5559, -5985, -6380, -6765, -7105, -7422,
#         -7706, -7955, -8163, -8339, -8470, -8557, -8600, -8618, -8585,
#         -8524, -8425, -8298, -8129, -7947, -7720, -7475, -7205, -6916,
#         -6606, -6266, -5922, -5556, -5165, -4774, -4353, -3922, -3476,
#         -3021], dtype=int16))

# %% [markdown]
# If we plot this array as a line graph, we'll get the familiar wave form representation:

# %%
import matplotlib.pyplot as plt

fs = mix_1_wave.getframerate()
timing = np.linspace(0, len(signal_1)/fs, num=len(signal_1))


plt.figure(figsize=(12,2))
plt.title('Recording 1')
plt.plot(timing,signal_1, c="#3ABFE7")
plt.ylim(-35000, 35000)
plt.show()

# %% [markdown]
# In the same way, we can now load the other two wave files, **[ICA mix 2.wav](ICA mix 2.wav)** and **[ICA mix 3.wav](ICA mix 3.wav)**

# %%
mix_2_wave.close()

# %%
mix_2_wave = wave.open('ICA mix 2.wav','r')

#Extract Raw Audio from Wav File
signal_raw_2 = mix_2_wave.readframes(-1)
signal_2 = np.frombuffer(signal_raw_2, 'int16')


mix_3_wave = wave.open('ICA mix 3.wav','r')

#Extract Raw Audio from Wav File
signal_raw_3 = mix_3_wave.readframes(-1)
signal_3 = np.frombuffer(signal_raw_3, 'int16')


plt.figure(figsize=(12,2))
plt.title('Recording 2')
plt.plot(timing,signal_2, c="#3ABFE7")
plt.ylim(-35000, 35000)
plt.show()


plt.figure(figsize=(12,2))
plt.title('Recording 3')
plt.plot(timing,signal_3, c="#3ABFE7")
plt.ylim(-35000, 35000)
plt.show()

# %% [markdown]
# Now that we've read all three files, we're ready to [zip](https://docs.python.org/3/library/functions.html#zip) them to create our dataset.
#
# * Create dataset ```X``` by zipping signal_1, signal_2, and signal_3 into a single list

# %%
X = list(zip(signal_1, signal_2, signal_3))

# Let's peak at what X looks like
X[:10]
# Out:
# [(879, 157, 879),
#  (1268, 899, 2584),
#  (1460, 1610, 4081),
#  (1756, 2325, 5682),
#  (1943, 3022, 7147),
#  (2216, 3718, 8689),
#  (2407, 4386, 10114),
#  (2668, 5056, 11583),
#  (2866, 5690, 12954),
#  (3106, 6318, 14327)]

# %% [markdown]
# We are now ready to run ICA to try to retrieve the original signals.
#
# * Import sklearn's [FastICA](http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FastICA.html) module
# * Initialize FastICA look for three components
# * Run the FastICA algorithm using fit_transform on dataset X

# %%
# TODO: Import FastICA
from sklearn.decomposition import FastICA

# TODO: Initialize FastICA with n_components=3
ica = FastICA(n_components=3)

# TODO: Run the FastICA algorithm using fit_transform on dataset X
ica_result = ica.fit_transform(X)
# Out:
# D:\Programs\Anaconda3\lib\site-packages\sklearn\decomposition\_fastica.py:494: FutureWarning: Starting in v1.3, whiten='unit-variance' will be used by default.
#   warnings.warn(

# %% [markdown]
# ```ica_result``` now contains the result of FastICA, which we hope are the original signals. It's in the shape:

# %%
ica_result.shape
# Out:
# (264515, 3)

# %% [markdown]
# Let's split into separate signals and look at them

# %%
result_signal_1 = ica_result[:,0]
result_signal_2 = ica_result[:,1]
result_signal_3 = ica_result[:,2]

# %% [markdown]
# Let's plot to see how the wave forms look

# %%
# Plot Independent Component #1
plt.figure(figsize=(12,2))
plt.title('Independent Component #1')
plt.plot(result_signal_1, c="#df8efd")
plt.ylim(-0.010, 0.010)
plt.show()

# Plot Independent Component #2
plt.figure(figsize=(12,2))
plt.title('Independent Component #2')
plt.plot(result_signal_2, c="#87de72")
plt.ylim(-0.010, 0.010)
plt.show()

# Plot Independent Component #3
plt.figure(figsize=(12,2))
plt.title('Independent Component #3')
plt.plot(result_signal_3, c="#f65e97")
plt.ylim(-0.010, 0.010)
plt.show()

# %% [markdown]
# Do some of these look like musical wave forms?
#
# The best way to confirm the result is to listen to resulting files. So let's save as wave files and verify. But before we do that, we'll have to:
# * convert them to integer (so we can save as PCM 16-bit Wave files), otherwise only some media players would be able to play them and others won't
# * Map the values to the appropriate range for int16 audio. That range is between -32768 and +32767. A basic mapping can be done by multiplying by 32767.
# * The sounds will be a little faint, we can increase the volume by multiplying by a value like 100

# %%
from scipy.io import wavfile

# Convert to int, map the appropriate range, and increase the volume a little bit
result_signal_1_int = np.int16(result_signal_1*32767*100)
result_signal_2_int = np.int16(result_signal_2*32767*100)
result_signal_3_int = np.int16(result_signal_3*32767*100)


# Write wave files
wavfile.write("result_signal_1.wav", fs, result_signal_1_int)
wavfile.write("result_signal_2.wav", fs, result_signal_2_int)
wavfile.write("result_signal_3.wav", fs, result_signal_3_int)

# %% [markdown]
# The resulting files we have now are: [note: make sure to lower the volume on your speakers first, just in case some problem caused the file to sound like static]
# * [result_signal_1.wav](result_signal_1.wav)
# * [result_signal_2.wav](result_signal_2.wav)
# * [result_signal_3.wav](result_signal_3.wav)
#
#
#
# Music:
# * Piano - The Carnival of the Animals - XIII. The Swan (Solo piano version). Performer: Markus Staab
# * Cello - Cello Suite no. 3 in C, BWV 1009 - I. Prelude. Performer: European Archive
