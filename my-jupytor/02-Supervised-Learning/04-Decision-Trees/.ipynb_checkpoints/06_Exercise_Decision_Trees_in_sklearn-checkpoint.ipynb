# %% [markdown]
# # Decision Trees in sklearn
#
# We have the following sample dataset, and our goal is to define a model that fives 100% accuracy on it.
#
# ![image.png](attachment:image.png)
#
# [data.csv](06_data.csv)

# %%
import pandas as pd
spreadsheet = pd.read_csv('./06_data.csv', delimiter = ',',header=None)
spreadsheet.head()
# Out:
#          0        1  2
# 0  0.24539  0.81725  0
# 1  0.21774  0.76462  0
# 2  0.20161  0.69737  0
# 3  0.20161  0.58041  0
# 4  0.24770  0.49561  0

# %%
# Import statements 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# Read the data.
data = np.asarray(pd.read_csv('./06_data.csv', header=None))
# Assign the features to the variable X, and the labels to the variable y. 
X = data[:,0:2]
y = data[:,2]

# Create the decision tree model and assign it to the variable model.
# You won't need to, but if you'd like, play with hyperparameters such
# as max_depth and min_samples_leaf and see what they do to the decision
# boundary.
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5)


# Fit the model.
model.fit(X, y)

#  Make predictions. Store them in the variable y_pred.
y_pred = model.predict([[0.1,0.2]])
print(y_pred)

# Calculate the accuracy and assign it to the variable acc.
acc = model.accuracy_score
print(acc)
# Out:
# [1.]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 29>()
#      26 print(y_pred)
#      28 # Calculate the accuracy and assign it to the variable acc.
# ---> 29 acc = model.accuracy_score()
#      30 print(acc)
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'accuracy_score'
