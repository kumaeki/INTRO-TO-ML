# %% [markdown]
# # Polynomial Kernel
#
# Sometimes a line will not be good enough to split our data. What we need is a more complex model.
#
# ![image.png](attachment:image.png)
#
#  To exploit that, we switch from a one-dimensional problem, the line, to a two-dimensional problem, the plane, by adding a y-axis.
#
#  ![image-2.png](attachment:image-2.png)
#
#  using the original SVM algorithm, we can find a good cut. It's the line $y = 4y=4$.
#
#  ![image-3.png](attachment:image-3.png)
#
#  By equating them, we get a new equation: $x^2 = 4 $ , which factors into two linear polynomials with solutions
#
# - $x =2$
# - $x = -2$
#
# So, those will make our boundary.
#
# We bring this back down to the line and we have $x =2$ and $x = -2$ as the boundaries for this model.
#
# ![image-4.png](attachment:image-4.png)
