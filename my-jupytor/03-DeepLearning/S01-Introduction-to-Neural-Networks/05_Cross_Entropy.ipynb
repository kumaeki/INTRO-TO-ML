# %% [markdown]
# # What's better than product?
#
# If we have thousands points, we will want to keep away from product.
#
# So use logarithm to convert product to sum.
#
# The good model give us a low cross entropy, and the bad model give us a high cross entropy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# and more than that, let's calculate every point, we will see,
#
# the points that are correctly classified have small values,
#
# and the points that are incorrectly classified have large values.
#
# It's easy to understand
#
# $$\log_{10}(1) = 0$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Formula of Cross-entropy
#
# $$CrossEntropy = -\sum_{i = 1}^{M}(y_iln(P_i) + (1 - y_i)ln(1-P_i))$$
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

# Write a function that takes as input two lists Y, P,
# and returns the float corresponding to their cross-entropy.
def cross_entropy(Y, P):
    Y = np.float_(Y)
    P = np.float_(P)
    return -np.sum(Y*np.log(P) + (1-Y)*np.log(1-P))

# %%
Y=[1,1,0]
P=[0.8,0.7,0.1]
print(cross_entropy(Y,P))
# Out:
# 0.6851790109107685

# %%
Y=[1,0,1,1]
P=[0.4,0.6,0.1,0.5]
print(cross_entropy(Y,P))
# Out:
# 4.828313737302301

# %% [markdown]
# # Multi-Class Cross-Entropy
#
# $$CrossEntropy = -\sum_{i = 1}^{n}\sum_{j = 1}^{M}y_{ij}ln(P_{ij})$$
#
# ![image.png](attachment:image.png)
