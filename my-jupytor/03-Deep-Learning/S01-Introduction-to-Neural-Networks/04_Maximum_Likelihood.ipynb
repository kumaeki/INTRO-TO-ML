# %% [markdown]
# # Maximum Likelihood
#
# We have two model as follow, which one is better?
#
# Right, but why ?
# ![image.png](attachment:image.png)

# %% [markdown]
# We calculate the probability of the four points are of the colors that they are actually are
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Now we know the right one is better, because it has the higher value
# ![image.png](attachment:image.png)
