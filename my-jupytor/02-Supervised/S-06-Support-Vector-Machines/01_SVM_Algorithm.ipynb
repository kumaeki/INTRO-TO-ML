# %% [markdown]
# # Problem
#
# There are some points, bule and red. We want to find a boundary that separates them.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Error Function
#
# But now we want the boundary to be as far away from the points as possible.
#
# To do this we add two boundaries (shown in the video as equidistant parallel lines to the main line), and try to maximize the distance between the two.
#
# There are two ways to measure the model:
#
# - By how many points it misclassifies
# - By how wide the margin is
#
# Our new error for this algorithm is going to be a classification error + a margin error.
#
# Minimizing this error is what's going to give us the algorithm for Support Vector Machines.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Perceptron Algorithm
#
# We have some data points like the blue and red, and we want to find a perfect line that splits them.
#
# A perfect line has the equation $W_x + b = 0$, where W and x are vectors and b is a scalar.
#
# So it looks more like this, $w_1x_1 + w_2x_2 + b = 0$
#
# ![image.png](attachment:image.png)
#
# To calculate the whole error that a model gives us, we add the errors of each individual misclassified point.
#
# We have two misclassifed red points with errors 2.5 and 0.5, and two miscalssified blue points with errors of 1 and 2.
#
# So this model gives us an error of 6.

# %% [markdown]
# # Classification Error
#
# The equation of the line is $W_x + b = 0$ .
#
# Now we don't just want a single line, we want the line with two extra lines that create the margin.
#
# And the equations for these lines are going to be
#
# - $Wx + b = 1$
# - $Wx + b = -1$
#
# Let's split the error in two. In order to **punish** the points that are within the margin
#
# - The blue error will now start from the bottom line
#
# - The red error is going to now start from the top line
#
# ![image.png](attachment:image.png)
#
# ### in order to build the error,  we take the absolute value of those errors and translate it by one
#
# - The blue error starts at zero on the bottom boundary line and increases by one with each step
# - Similarly, the red error is going to be zero on the top boundary line and then increase linearly in the opposite direction.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Margin Error
#
# The margin is the distance between the two lines, and we want to turn this margin into an error that we can minimize using gradient descent.
#
# We want a function that gives us a small error for the large margin case, and a large error for the small margin case.
#
# This is because our goal is to obtain a model that has as large a margin as possible.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # The C Parameter
#
# Think about this question
#
# ![image-2.png](attachment:image-2.png)
#
# It depends a lot on the data and the problem that we're approaching, which means that we need some flexibility.
#
# That flexibility is going to be provided by the C parameter.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # SVM Algorithm
#
#
# Minimize the error using gradient descent
#
# $$Error = C * Classification Error + Margin Error$$
